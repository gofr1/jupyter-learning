# %% [markdown]
# ## Retrieve data from DataFrame with Collect

# %% [markdown]
# PySpark RDD/DataFrame `collect()` is an action operation that is used to retrieve all the elements of the dataset (from all nodes) to the driver node. We should use the `collect()` on smaller dataset usually after `filter()`, `group()` e.t.c.

# %%
dbutils.library.restartPython() # Removes Python state, but some libraries might not work without calling this command.dbutils.restartPython()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Load libraries

# %%
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import IntegerType, DateType, StringType, StructType, StructField, ArrayType, MapType
from pyspark.sql.functions import lit, col, expr, when
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Create Spark session

# %%
spark = SparkSession.builder.appName('Retrieve data from DataFrame with Collect').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Prepare Data

# %%
data = [
  ('John', '', 'Smith', '36636', 'M', 2500),
  ('Jane', '', 'Doe', '42114', 'F', 500),
  ('Richard', 'Laurence', 'Marquette', '97086', 'M', 1500),
  ('Israel', '', 'Israeli', '', 'M', 3000),
  ('Edward', 'III', '', 'SL4', 'M', 5000)
]
 
schema = StructType([
  StructField('firstname', StringType(),True),
  StructField('middlename', StringType(),True),
  StructField('lastname', StringType(),True),
  StructField('zip', StringType(), True),
  StructField('gender', StringType(), True),
  StructField('salary', IntegerType(), True)
])

columns = schema.fieldNames()

df = spark.createDataFrame(data=data, schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- firstname: string (nullable = true)
# -- middlename: string (nullable = true)
# -- lastname: string (nullable = true)
# -- zip: string (nullable = true)
# -- gender: string (nullable = true)
# -- salary: integer (nullable = true)
#
# +---------+----------+---------+-----+------+------+
# firstname|middlename|lastname |zip  |gender|salary|
# +---------+----------+---------+-----+------+------+
# John     |          |Smith    |36636|M     |2500  |
# Jane     |          |Doe      |42114|F     |500   |
# Richard  |Laurence  |Marquette|97086|M     |1500  |
# Israel   |          |Israeli  |     |M     |3000  |
# Edward   |III       |         |SL4  |M     |5000  |
# +---------+----------+---------+-----+------+------+
#
# </div>

# %% [markdown]
# #### Let’s use the collect() to retrieve the data

# %%
# Retrieves all elements in a DataFrame as an Array of Row type to the driver node
dataCollect = df.collect()
print(dataCollect)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(firstname=&#39;John&#39;, middlename=&#39;&#39;, lastname=&#39;Smith&#39;, zip=&#39;36636&#39;, gender=&#39;M&#39;, salary=2500), Row(firstname=&#39;Jane&#39;, middlename=&#39;&#39;, lastname=&#39;Doe&#39;, zip=&#39;42114&#39;, gender=&#39;F&#39;, salary=500), Row(firstname=&#39;Richard&#39;, middlename=&#39;Laurence&#39;, lastname=&#39;Marquette&#39;, zip=&#39;97086&#39;, gender=&#39;M&#39;, salary=1500), Row(firstname=&#39;Israel&#39;, middlename=&#39;&#39;, lastname=&#39;Israeli&#39;, zip=&#39;&#39;, gender=&#39;M&#39;, salary=3000), Row(firstname=&#39;Edward&#39;, middlename=&#39;III&#39;, lastname=&#39;&#39;, zip=&#39;SL4&#39;, gender=&#39;M&#39;, salary=5000)]
# </div>

# %%
for row in dataCollect:
    print(f'{row["firstname"]}, {row["gender"]}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">John, M
# Jane, F
# Richard, M
# Israel, M
# Edward, M
# </div>

# %%
df.collect()[0][0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: &#39;John&#39;</div>

# %% [markdown]
# #### When to avoid Collect()
#
# Usually, `collect()` is used to retrieve the action output when you have very small result set and calling `collect()` on an RDD/DataFrame with a bigger result set causes out of memory as it returns the entire dataset (from all workers) to the driver hence we should avoid calling `collect()` on a larger dataset.
#
# #### collect() vs select()
#
# `select()` is a transformation that returns a new DataFrame and holds the columns that are selected whereas `collect()` is an action that returns the entire data set in an Array to the driver.

# %% [markdown]
# #### The end of the notebook
