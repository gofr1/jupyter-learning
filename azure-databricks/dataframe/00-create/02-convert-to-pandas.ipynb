# %% [markdown]
# ## Convert PySpark DataFrame to Pandas

# %%
dbutils.library.restartPython() # Removes Python state, but some libraries might not work without calling this command.dbutils.restartPython()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Load libraries

# %%
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import IntegerType, DateType, StringType, StructType, StructField
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Create Spark session

# %%
spark = SparkSession.builder.appName('Convert dataframe from pyspark to pandas').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Prepare Data

# %%
data = [
  ('John', '', 'Smith', '36636', 'M', 2500),
  ('Jane', '', 'Doe', '42114', 'F', 500),
  ('Richard', 'Laurence', 'Marquette', '97086', 'M', 1500),
  ('Israel', '', 'Israeli', '', 'M', 3000),
  ('Edward', 'III', '', 'SL4', 'M', 5000)
]
 
columns = ['firstname', 'middlename', 'lastname', 'zip', 'gender', 'salary']
 
pysparkDF = spark.createDataFrame(data=data, schema=columns)
pysparkDF.printSchema()
pysparkDF.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- firstname: string (nullable = true)
# -- middlename: string (nullable = true)
# -- lastname: string (nullable = true)
# -- zip: string (nullable = true)
# -- gender: string (nullable = true)
# -- salary: long (nullable = true)
#
# +---------+----------+---------+-----+------+------+
# firstname|middlename|lastname |zip  |gender|salary|
# +---------+----------+---------+-----+------+------+
# John     |          |Smith    |36636|M     |2500  |
# Jane     |          |Doe      |42114|F     |500   |
# Richard  |Laurence  |Marquette|97086|M     |1500  |
# Israel   |          |Israeli  |     |M     |3000  |
# Edward   |III       |         |SL4  |M     |5000  |
# +---------+----------+---------+-----+------+------+
#
# </div>

# %% [markdown]
# #### Convert PySpark Dataframe to Pandas DataFrame

# %%
pandasDF = pysparkDF.toPandas()
print(pandasDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">  firstname middlename   lastname    zip gender  salary
# 0      John                 Smith  36636      M    2500
# 1      Jane                   Doe  42114      F     500
# 2   Richard   Laurence  Marquette  97086      M    1500
# 3    Israel               Israeli             M    3000
# 4    Edward        III               SL4      M    5000
# </div>

# %% [markdown]
# #### Convert PySpark Nested Struct DataFrame to Pandas

# %%
dataNested = [
  (('John', '', 'Smith'), '36636', 'M', 2500),
  (('Jane', '', 'Doe'), '42114', 'F', 500),
  (('Richard', 'Laurence', 'Marquette'), '97086', 'M', 1500),
  (('Israel', '', 'Israeli'), '', 'M', 3000),
  (('Edward', 'III', ''), 'SL4', 'M', 5000)
]
 
schemaNested = StructType([
   StructField('name', StructType([
     StructField('firstname', StringType(), True),
     StructField('middlename', StringType(), True),
     StructField('lastname', StringType(), True)
     ])),
   StructField('zip', StringType(), True),
   StructField('gender', StringType(), True),
   StructField('salary', StringType(), True)
])

pysparkNestedDF = spark.createDataFrame(data=dataNested, schema=schemaNested)
pysparkNestedDF.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- name: struct (nullable = true)
#     |-- firstname: string (nullable = true)
#     |-- middlename: string (nullable = true)
#     |-- lastname: string (nullable = true)
# -- zip: string (nullable = true)
# -- gender: string (nullable = true)
# -- salary: string (nullable = true)
#
# </div>

# %%
pandasNestedDF = pysparkNestedDF.toPandas()
print(pandasNestedDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">                                                name    zip gender salary
# 0  {&#39;firstname&#39;: &#39;John&#39;, &#39;middlename&#39;: &#39;&#39;, &#39;lastn...  36636      M   2500
# 1  {&#39;firstname&#39;: &#39;Jane&#39;, &#39;middlename&#39;: &#39;&#39;, &#39;lastn...  42114      F    500
# 2  {&#39;firstname&#39;: &#39;Richard&#39;, &#39;middlename&#39;: &#39;Lauren...  97086      M   1500
# 3  {&#39;firstname&#39;: &#39;Israel&#39;, &#39;middlename&#39;: &#39;&#39;, &#39;las...             M   3000
# 4  {&#39;firstname&#39;: &#39;Edward&#39;, &#39;middlename&#39;: &#39;III&#39;, &#39;...    SL4      M   5000
# </div>

# %% [markdown]
# #### The end of the notebook
