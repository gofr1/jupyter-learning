# %% [markdown]
# ## Row using on DataFrame and RDD

# %% [markdown]
# pyspark.sql.Row which is represented as a record/row in DataFrame, one can create a Row object by using named arguments, or create a custom Row like class.
#
# Let's see how to use Row class with named argument and defining realtime class and using it on DataFrame & RDD.

# %%
dbutils.library.restartPython() # Removes Python state, but some libraries might not work without calling this command.dbutils.restartPython()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Load libraries

# %%
from pyspark.sql import SparkSession, Row
from pyspark.sql.types import IntegerType, DateType, StringType, StructType, StructField
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Create Spark session

# %%
spark = SparkSession.builder.appName('Row using on DataFrame and RDD').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Create a Row Object

# %%
row=Row('Elijah',36)
print(f'{row[0]}, {row[1]}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Elijah, 36
# </div>

# %%
row=Row(name='Gregory', age=9)
print(f'{row.name}, {row.age}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Gregory, 9
# </div>

# %% [markdown]
# #### Create Custom Class from Row

# %%
Person = Row('name', 'age')
p1=Person('Elijah',36)
p2=Person('Gregory',9)
print(f'{p1.name}, {p2.name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Elijah, Gregory
# </div>

# %% [markdown]
# #### Using Row class on PySpark RDD

# %%
data = [
  Row(name='John,,Doe',lang=['Python','R','SQL'],country='USA'), 
  Row(name='Richard,Lionheart,',lang=['C#','C','C++'],country='England'),
  Row(name='Oscar,Fingal O\'Flahertie Wills,Wilde',lang=['Kotlin','JavaScript'],country='Ireland')
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
rdd=spark.sparkContext.parallelize(data)
print(rdd.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(name=&#39;John,,Doe&#39;, lang=[&#39;Python&#39;, &#39;R&#39;, &#39;SQL&#39;], country=&#39;USA&#39;), Row(name=&#39;Richard,Lionheart,&#39;, lang=[&#39;C#&#39;, &#39;C&#39;, &#39;C++&#39;], country=&#39;England&#39;), Row(name=&#34;Oscar,Fingal O&#39;Flahertie Wills,Wilde&#34;, lang=[&#39;Kotlin&#39;, &#39;JavaScript&#39;], country=&#39;Ireland&#39;)]
# </div>

# %%
# Let’s collect the data and access the data using its properties.
collData=rdd.collect()
for row in collData:
    print(f'{row.name}, {row.lang}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">John,,Doe, [&#39;Python&#39;, &#39;R&#39;, &#39;SQL&#39;]
# Richard,Lionheart,, [&#39;C#&#39;, &#39;C&#39;, &#39;C++&#39;]
# Oscar,Fingal O&#39;Flahertie Wills,Wilde, [&#39;Kotlin&#39;, &#39;JavaScript&#39;]
# </div>

# %%
# Using Person class
Person=Row('name','lang','country')
data = [
  Person('John,,Doe',['Python','R','SQL'],'USA'), 
  Person('Richard,Lionheart,',['C#','C','C++'],'England'),
  Person('Oscar,Fingal O\'Flahertie Wills,Wilde',['Kotlin','JavaScript'],'Ireland')
]
rdd=spark.sparkContext.parallelize(data)
print(rdd.collect())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Row(name=&#39;John,,Doe&#39;, lang=[&#39;Python&#39;, &#39;R&#39;, &#39;SQL&#39;], country=&#39;USA&#39;), Row(name=&#39;Richard,Lionheart,&#39;, lang=[&#39;C#&#39;, &#39;C&#39;, &#39;C++&#39;], country=&#39;England&#39;), Row(name=&#34;Oscar,Fingal O&#39;Flahertie Wills,Wilde&#34;, lang=[&#39;Kotlin&#39;, &#39;JavaScript&#39;], country=&#39;Ireland&#39;)]
# </div>

# %% [markdown]
# #### Using Row class on PySpark DataFrame

# %%
data = [
  Row(name='John,,Doe',lang=['Python','R','SQL'],country='USA'), 
  Row(name='Richard,Lionheart,',lang=['C#','C','C++'],country='England'),
  Row(name='Oscar,Fingal O\'Flahertie Wills,Wilde',lang=['Kotlin','JavaScript'],country='Ireland')
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df=spark.createDataFrame(data)
df.printSchema()
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- name: string (nullable = true)
# -- lang: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- country: string (nullable = true)
#
# +--------------------+--------------------+-------+
#                 name|                lang|country|
# +--------------------+--------------------+-------+
#            John,,Doe|    [Python, R, SQL]|    USA|
#   Richard,Lionheart,|        [C#, C, C++]|England|
# Oscar,Fingal O&#39;Fl...|[Kotlin, JavaScript]|Ireland|
# +--------------------+--------------------+-------+
#
# </div>

# %%
data = [
  Row('John,,Doe',['Python','R','SQL'],'USA'), 
  Row('Richard,Lionheart,',['C#','C','C++'],'England'),
  Row('Oscar,Fingal O\'Flahertie Wills,Wilde',['Kotlin','JavaScript'],'Ireland')
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# If you want to apply specific column names, or they are not specified for input
columns = ['name','languagesAtSchool','currentState']
df=spark.createDataFrame(data).toDF(*columns)
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- name: string (nullable = true)
# -- languagesAtSchool: array (nullable = true)
#     |-- element: string (containsNull = true)
# -- currentState: string (nullable = true)
#
# </div>

# %% [markdown]
# #### Create Nested Struct Using Row Class

# %%
data=[
  Row(name='John',prop=Row(hair='black',eye='brown')),
  Row(name='Marie',prop=Row(hair='blond',eye='black'))
]

df=spark.createDataFrame(data)
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- name: string (nullable = true)
# -- prop: struct (nullable = true)
#     |-- hair: string (nullable = true)
#     |-- eye: string (nullable = true)
#
# </div>

# %% [markdown]
# #### The end of the notebook
