# %%
dbutils.widgets.text('d', '','')
dbutils.widgets.get('d')
d_arg = getArgument('d')

if d_arg in ('', None):
  d = 0
else:
  d = int(d_arg)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
a = 10

try:
  b = a/d
  dbutils.notebook.exit('OK')
except Exception as e:
  dbutils.notebook.exit(e)
# Out:
# division by zero

# %%
# The End
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
