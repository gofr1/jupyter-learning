# %%
# Errors in workflows thrown a WorkflowException.

def run_with_retry(notebook, timeout, args = {}, max_retries = 3):
  num_retries = 1
  while True:
#    try:
      return dbutils.notebook.run(notebook, timeout, args)
#    except Exception as e:
#      if num_retries >= max_retries:
#        raise e
#      else:
#        print("Retrying error", e)
#        num_retries += 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
for d in range(5):
  run_stat = run_with_retry("callee-notebook", 50, args = {"d": d}, max_retries = 1)
  print(run_stat)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">division by zero
# OK
# OK
# OK
# OK
# </div>

# %%
# The End
