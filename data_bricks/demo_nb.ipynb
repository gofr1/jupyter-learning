# %%
# %sql
SELECT * FROM sales_records_
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.format("csv").option("header","true").load("dbfs:/FileStore/tables/5m_Sales_Records.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.registerTempTable("sales")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spark.sql("SELECT Country, SUM(CAST(`Total Cost` AS DOUBLE)) as `Total Cost`, SUM(CAST(`Total Revenue` AS DOUBLE)) as `Total Revenue`, SUM(CAST(`Total Profit` AS DOUBLE)) as `Total Profit` FROM sales WHERE Country IN ('Russia', 'Poland', 'India') GROUP BY Country ORDER BY Country"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>Total Cost</th><th>Total Revenue</th><th>Total Profit</th></tr></thead><tbody><tr><td>India</td><td>2.5414733548470016E10</td><td>3.606169367596E10</td><td>1.0646960127490002E10</td></tr><tr><td>Poland</td><td>2.529781489388002E10</td><td>3.588189261702003E10</td><td>1.0584077723140009E10</td></tr><tr><td>Russia</td><td>2.5397704604050003E10</td><td>3.601419270280999E10</td><td>1.0616488098760014E10</td></tr></tbody></table></div>
